# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from data_providers import *
from utils.utils import AverageMeter
from thop import profile

# %%
import pandas as pd
pd.read_csv('harblocks.csv')
# Out:
#    dataset  batch  window_size        block  kernel  input_channels  \
# 0      uci      1          128    LSTMBlock       0              32
# 1      uci      1          128    LSTMBlock       0              32
# 2      uci      1          128    LSTMBlock       0              32
# 3      uci      1          128    LSTMBlock       0              32
# 4      uci      1          128    LSTMBlock       0              32
# ..     ...    ...          ...          ...     ...             ...
# 95     uci      1          128  BiLSTMBlock       0              32
# 96     uci      1          128  BiLSTMBlock       0              32
# 97     uci      1          128  BiLSTMBlock       0              32
# 98     uci      1          128  BiLSTMBlock       0              32
# 99     uci      1          128  BiLSTMBlock       0              32
#
#     out_channels  num_layers hardware device   latency
# 0             32           1       pc    cpu  0.001637
# 1             32           1       pc    cpu  0.001720
# 2             32           1       pc    cpu  0.001556
# 3             32           1       pc    cpu  0.001666
# 4             32           1       pc    cpu  0.001603
# ..           ...         ...      ...    ...       ...
# 95           128           1       pc    gpu  0.692719
# 96           128           1       pc    gpu  0.692243
# 97           128           1       pc    gpu  0.701003
# 98           128           1       pc    gpu  0.706901
# 99           128           1       pc    gpu  0.731740
#
# [100 rows x 11 columns]

# %% [markdown]
# # All Blocks

# %%
block_list = ['LSTMBlock', 'BiLSTMBlock', 'GTSResConvBlock']
lstm_block_list = ['LSTMBlock', 'BiLSTMBlock']

# %% [markdown]
# * cpu

# %%
for block in block_list:
    for _ in range(10):
        ! python measure_blocks/measure_harblock_latency.py --hardware pc --device cpu --dataset uci --block_name $block --num-runs 100 --config_file harblocks.csv
        
for block in lstm_block_list:
    for _ in range(10):
        ! python measure_blocks/measure_harblock_latency.py --hardware pc --device cpu --dataset uci --block_name $block --out_channels 128 --num-runs 100 --config_file harblocks.csv
# Out:
# LSTMBlock: 0.001637
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.001720
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.001556
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.001666
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.001603
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.001648
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.001690
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.001667
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.001676
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.001626
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001728
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001786
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001699
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001644
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001713
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001644
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001684
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001735
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001751
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001690
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 0.001663
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 0.001682
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 0.001625
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 0.001634
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 0.001667
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 0.001716
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 0.001666
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 0.001633
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 0.001683
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 0.001716
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.001779
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.001739
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.001698
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.001560
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.001644
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.001747
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.001678
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.001650
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.001644
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.001685
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001667
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001684
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001793
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001682
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001752
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001696
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001636
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001530
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001768
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.001641
# Experiment results saved to harblocks.csv

# %% [markdown]
# * gpu

# %%
for block in block_list:
    for _ in range(10):
        ! python measure_blocks/measure_harblock_latency.py --hardware pc --device gpu --dataset uci --block_name $block --num-runs 100 --config_file harblocks.csv
        
for block in lstm_block_list:
    for _ in range(10):
        ! python measure_blocks/measure_harblock_latency.py --hardware pc --device gpu --dataset uci --block_name $block --out_channels 128 --num-runs 100 --config_file harblocks.csv
# Out:
# LSTMBlock: 0.085980
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.085437
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.085433
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.085749
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.085524
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.086058
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.086566
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.085980
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.086241
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.085933
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.162778
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.163076
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.163810
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.163649
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.163552
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.163891
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.163805
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.163836
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.164716
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.163924
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 2.026649
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 1.807261
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 1.702779
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 1.774188
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 1.801115
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 1.838060
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 1.700431
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 1.721952
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 1.724605
# Experiment results saved to harblocks.csv
# GTSResConvBlock: 1.847535
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.346172
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.348426
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.353578
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.346897
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.348941
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.351649
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.348148
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.355031
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.349144
# Experiment results saved to harblocks.csv
# LSTMBlock: 0.349206
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.725273
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.698606
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.721809
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.689875
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.698750
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.692719
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.692243
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.701003
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.706901
# Experiment results saved to harblocks.csv
# BiLSTMBlock: 0.731740
# Experiment results saved to harblocks.csv

# %% [markdown]
# * ETC

# %%
def get_bin_dist(input_tensor, num_bins=10):
    min_value, _ = input_tensor.min(dim=2)
    max_value, _ = input_tensor.max(dim=2)
    
    fractions = torch.empty(input_tensor.shape[0], input_tensor.shape[1], num_bins).to(input_tensor.device)   # batch, num_bins
    for i in range(min_value.shape[-1]):
        histogram = torch.histc(input_tensor[0][i], bins=num_bins, min=min_value[0][i], max=max_value[0][i])
        fractions[0][i] = histogram / input_tensor.shape[-1]

    return fractions.reshape(-1, input_tensor.shape[1]*num_bins)

def get_stats_feats(input_tensor, num_bins=10):
    avg = torch.mean(input_tensor, dim=2)
    std = torch.std(input_tensor, dim=2)
    avg_abs_diff = torch.abs(input_tensor - axis_avg.unsqueeze(2)).mean(dim=2)
    avg_resultant = input_tensor.pow(2).sum(dim=1).sqrt().mean(dim=1).unsqueeze(1)
    bin_dist = get_bin_dist(input_tensor, num_bins=10)
    feats = torch.cat([avg, std, avg_abs_diff, avg_resultant, bin_dist], dim=1)
    return feats

# %%
avg = torch.mean(input_tensor, dim=2)
std = torch.std(input_tensor, dim=2)
avg_abs_diff = torch.abs(input_tensor - axis_avg.unsqueeze(2)).mean(dim=2)
avg_resultant = input_tensor.pow(2).sum(dim=1).sqrt().mean(dim=1).unsqueeze(1)
bin_dist = get_bin_dist(input_tensor, num_bins=10)

# %%
get_stats_feats(input_tensor).shape
# Out:
# torch.Size([1, 79])

# %%
axis_avg.shape, axis_std.shape, axis_avg_abs_diff.shape, avg_resultant.shape, bin_dist.shape
# Out:
# (torch.Size([1, 6]),
#  torch.Size([1, 6]),
#  torch.Size([1, 6]),
#  torch.Size([1, 1]),
#  torch.Size([1, 60]))

# %%
class BasicConv1d(nn.Module):
    def __init__(self, i_nc, o_nc, **kwargs):
        super(BasicConv1d, self).__init__()
        self.conv = nn.Conv1d(i_nc, o_nc, **kwargs)
    def forward(self, x):
        x = self.conv(x)
        return F.relu_(x)

class RTCNN(nn.Module):
    def __init__(self, window_size, init_channels, num_classes, acc_num):
        super(RTCNN, self).__init__()
        self.accs = acc_num
        
        self.conv = BasicConv1d(init_channels, 196, kernel_size=16, stride=1, padding=8)
        self.maxpool = nn.MaxPool1d(kernel_size=4, stride=4, padding=0)

        self.fc = nn.Sequential(
            nn.Linear(flat_size + 40*acc_num, 1024),
            nn.ReLU(),
            nn.Dropout(0.05),
            nn.Linear(1024, num_classes)
        )

    def forward(self, x):
        stats = get_stats_feats(x)
        x = self.conv(x)
        x = self.maxpool(x)

        x = x.view(x.size(0), -1)
        x = torch.cat([x, stats], dim=1)
        logits = self.fc(x)

        return logits
# Out:
# torch.return_types.min(
# values=tensor([[-3.0980, -2.5481, -3.6223, -2.4390, -3.1402, -3.5049]]),
# indices=tensor([[ 51, 122,  61,   5, 111,  74]]))
