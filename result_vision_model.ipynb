# %%
import argparse
import os
import sys
import math
import torch
import torch.nn as nn
import pandas as pd

from thop import profile

from utils.utils import AverageMeter

from data_providers import UCIHARDataProvider, OPPDataProvider, KUHARDataProvider, UniMiBDataProvider, WISDMDataProvider

# %%
pd.read_csv('vision.csv')
# Out:
#    dataset  batch         model hardware device   latency
# 0      uci      1  mobilenet_v2       pc    cpu  0.001688
# 1      uci      1  mobilenet_v2       pc    cpu  0.001703
# 2      uci      1  mobilenet_v2       pc    cpu  0.001851
# 3      uci      1  mobilenet_v2       pc    cpu  0.001718
# 4      uci      1  mobilenet_v2       pc    cpu  0.001763
# 5      uci      1  mobilenet_v2       pc    cpu  0.001763
# 6      uci      1  mobilenet_v2       pc    cpu  0.001705
# 7      uci      1  mobilenet_v2       pc    cpu  0.001758
# 8      uci      1  mobilenet_v2       pc    cpu  0.001734
# 9      uci      1  mobilenet_v2       pc    gpu  4.591141
# 10     uci      1  mobilenet_v2       pc    gpu  4.478848
# 11     uci      1  mobilenet_v2       pc    gpu  4.502964
# 12     uci      1  mobilenet_v2       pc    gpu  4.485481
# 13     uci      1  mobilenet_v2       pc    gpu  4.516294
# 14     uci      1  mobilenet_v2       pc    gpu  4.447314
# 15     uci      1  mobilenet_v2       pc    gpu  4.637302
# 16     uci      1  mobilenet_v2       pc    gpu  4.412537
# 17     uci      1  mobilenet_v2       pc    gpu  4.558695
# 18     uci      1  mobilenet_v2       pc    gpu  4.522512

# %% [markdown]
# # All Model

# %%
model_list = ["mobilenet_v2", "mobilenet_v3_small", "mobilenet_v3_large", "mnasnet0_5", "mnasnet0_75", "mnasnet1_0", "mnasnet1_3", "shufflenet_v2_x0_5", "shufflenet_v2_x1_0", "shufflenet_v2_x1_5", "shufflenet_v2_x2_0", "resnet18", "resnet34", "resnet50", "resnet101", "resnext50_32x4d", "resnext101_32x8d", "resnext101_64x4d", "squeezenet1_0", "squeezenet1_1"]

# %% [markdown]
# * cpu

# %%
for model in model_list:
    for i in range(10):
        ! python measure_vismodel_latency.py --hardware pc --device cpu --dataset uci --arch $model --num-runs 100 --config_file vision.csv
# Out:
# mobilenet_v2: 0.001731
# Experiment results saved to vision.csv
# mobilenet_v2: 0.001715
# Experiment results saved to vision.csv
# mobilenet_v2: 0.001668
# Experiment results saved to vision.csv
# mobilenet_v2: 0.001738
# Experiment results saved to vision.csv
# mobilenet_v2: 0.001676
# Experiment results saved to vision.csv
# mobilenet_v2: 0.001745
# Experiment results saved to vision.csv
# mobilenet_v2: 0.001716
# Experiment results saved to vision.csv
# mobilenet_v2: 0.001712
# Experiment results saved to vision.csv
# mobilenet_v2: 0.001780
# Experiment results saved to vision.csv
# mobilenet_v2: 0.001686
# Experiment results saved to vision.csv
# mobilenet_v3_small: 0.001743
# Experiment results saved to vision.csv
# mobilenet_v3_small: 0.001702
# Experiment results saved to vision.csv
# mobilenet_v3_small: 0.001768
# Experiment results saved to vision.csv
# mobilenet_v3_small: 0.001625
# Experiment results saved to vision.csv
# mobilenet_v3_small: 0.001676
# Experiment results saved to vision.csv
# mobilenet_v3_small: 0.001702
# Experiment results saved to vision.csv
# mobilenet_v3_small: 0.001752
# Experiment results saved to vision.csv
# mobilenet_v3_small: 0.001670
# Experiment results saved to vision.csv
# mobilenet_v3_small: 0.001742
# Experiment results saved to vision.csv
# mobilenet_v3_small: 0.001731
# Experiment results saved to vision.csv
# mobilenet_v3_large: 0.001734
# Experiment results saved to vision.csv
# mobilenet_v3_large: 0.001749
# Experiment results saved to vision.csv
# mobilenet_v3_large: 0.001715
# Experiment results saved to vision.csv
# mobilenet_v3_large: 0.001784
# Experiment results saved to vision.csv
# mobilenet_v3_large: 0.001725
# Experiment results saved to vision.csv
# mobilenet_v3_large: 0.001743
# Experiment results saved to vision.csv
# mobilenet_v3_large: 0.001709
# Experiment results saved to vision.csv
# mobilenet_v3_large: 0.001799
# Experiment results saved to vision.csv
# mobilenet_v3_large: 0.001738
# Experiment results saved to vision.csv
# mobilenet_v3_large: 0.001705
# Experiment results saved to vision.csv
# mnasnet0_5: 0.001702
# Experiment results saved to vision.csv
# mnasnet0_5: 0.001644
# Experiment results saved to vision.csv
# mnasnet0_5: 0.001656
# Experiment results saved to vision.csv
# mnasnet0_5: 0.001654
# Experiment results saved to vision.csv
# mnasnet0_5: 0.001688
# Experiment results saved to vision.csv
# mnasnet0_5: 0.001651
# Experiment results saved to vision.csv
# mnasnet0_5: 0.001638
# Experiment results saved to vision.csv
# mnasnet0_5: 0.001769
# Experiment results saved to vision.csv
# mnasnet0_5: 0.001702
# Experiment results saved to vision.csv
# mnasnet0_5: 0.001778
# Experiment results saved to vision.csv
# mnasnet0_75: 0.001655
# Experiment results saved to vision.csv
# mnasnet0_75: 0.001712
# Experiment results saved to vision.csv
# mnasnet0_75: 0.001728
# Experiment results saved to vision.csv
# mnasnet0_75: 0.001661
# Experiment results saved to vision.csv
# mnasnet0_75: 0.001660
# Experiment results saved to vision.csv
# mnasnet0_75: 0.001840
# Experiment results saved to vision.csv
# mnasnet0_75: 0.001618
# Experiment results saved to vision.csv
# mnasnet0_75: 0.001705
# Experiment results saved to vision.csv
# mnasnet0_75: 0.001715
# Experiment results saved to vision.csv
# mnasnet0_75: 0.001793
# Experiment results saved to vision.csv
# mnasnet1_0: 0.001707
# Experiment results saved to vision.csv
# mnasnet1_0: 0.001780
# Experiment results saved to vision.csv
# mnasnet1_0: 0.001744
# Experiment results saved to vision.csv
# mnasnet1_0: 0.001749
# Experiment results saved to vision.csv
# mnasnet1_0: 0.001641
# Experiment results saved to vision.csv
# mnasnet1_0: 0.001627
# Experiment results saved to vision.csv
# mnasnet1_0: 0.001760
# Experiment results saved to vision.csv
# mnasnet1_0: 0.001679
# Experiment results saved to vision.csv
# mnasnet1_0: 0.001738
# Experiment results saved to vision.csv
# mnasnet1_0: 0.001668
# Experiment results saved to vision.csv
# mnasnet1_3: 0.001649
# Experiment results saved to vision.csv
# mnasnet1_3: 0.001816
# Experiment results saved to vision.csv
# mnasnet1_3: 0.001692
# Experiment results saved to vision.csv
# mnasnet1_3: 0.001768
# Experiment results saved to vision.csv
# mnasnet1_3: 0.001705
# Experiment results saved to vision.csv
# mnasnet1_3: 0.001721
# Experiment results saved to vision.csv
# mnasnet1_3: 0.001708
# Experiment results saved to vision.csv
# mnasnet1_3: 0.001748
# Experiment results saved to vision.csv
# mnasnet1_3: 0.001719
# Experiment results saved to vision.csv
# mnasnet1_3: 0.001739
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 0.001737
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 0.001628
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 0.001770
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 0.001710
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 0.001658
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 0.001733
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 0.001750
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 0.001682
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 0.001671
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 0.001647
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 0.001742
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 0.001849
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 0.001669
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 0.001620
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 0.001741
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 0.001761
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 0.001691
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 0.001688
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 0.001672
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 0.001727
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 0.001770
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 0.001705
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 0.001737
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 0.001765
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 0.001646
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 0.001648
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 0.001740
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 0.001744
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 0.001727
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 0.001713
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 0.001728
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 0.001756
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 0.001548
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 0.001741
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 0.001767
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 0.001719
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 0.001789
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 0.001722
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 0.001689
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 0.001757
# Experiment results saved to vision.csv
# resnet18: 0.001705
# Experiment results saved to vision.csv
# resnet18: 0.001700
# Experiment results saved to vision.csv
# resnet18: 0.001715
# Experiment results saved to vision.csv
# resnet18: 0.001683
# Experiment results saved to vision.csv
# resnet18: 0.001742
# Experiment results saved to vision.csv
# resnet18: 0.001759
# Experiment results saved to vision.csv
# resnet18: 0.001718
# Experiment results saved to vision.csv
# resnet18: 0.001733
# Experiment results saved to vision.csv
# resnet18: 0.001655
# Experiment results saved to vision.csv
# resnet18: 0.001744
# Experiment results saved to vision.csv
# resnet34: 0.001742
# Experiment results saved to vision.csv
# resnet34: 0.001682
# Experiment results saved to vision.csv
# resnet34: 0.001612
# Experiment results saved to vision.csv
# resnet34: 0.001663
# Experiment results saved to vision.csv
# resnet34: 0.001624
# Experiment results saved to vision.csv
# resnet34: 0.001576
# Experiment results saved to vision.csv
# resnet34: 0.001830
# Experiment results saved to vision.csv
# resnet34: 0.001751
# Experiment results saved to vision.csv
# resnet34: 0.001614
# Experiment results saved to vision.csv
# resnet34: 0.001766
# Experiment results saved to vision.csv
# resnet50: 0.001688
# Experiment results saved to vision.csv
# resnet50: 0.001743
# Experiment results saved to vision.csv
# resnet50: 0.001678
# Experiment results saved to vision.csv
# resnet50: 0.001693
# Experiment results saved to vision.csv
# resnet50: 0.001675
# Experiment results saved to vision.csv
# resnet50: 0.001764
# Experiment results saved to vision.csv
# resnet50: 0.001666
# Experiment results saved to vision.csv
# resnet50: 0.001686
# Experiment results saved to vision.csv
# resnet50: 0.001695
# Experiment results saved to vision.csv
# resnet50: 0.001729
# Experiment results saved to vision.csv
# resnet101: 0.001831
# Experiment results saved to vision.csv
# resnet101: 0.001729
# Experiment results saved to vision.csv
# resnet101: 0.001791
# Experiment results saved to vision.csv
# resnet101: 0.001827
# Experiment results saved to vision.csv
# resnet101: 0.001869
# Experiment results saved to vision.csv
# resnet101: 0.001739
# Experiment results saved to vision.csv
# resnet101: 0.001796
# Experiment results saved to vision.csv
# resnet101: 0.001802
# Experiment results saved to vision.csv
# resnet101: 0.001829
# Experiment results saved to vision.csv
# resnet101: 0.001748
# Experiment results saved to vision.csv
# resnext50_32x4d: 0.001867
# Experiment results saved to vision.csv
# resnext50_32x4d: 0.001782
# Experiment results saved to vision.csv
# resnext50_32x4d: 0.001762
# Experiment results saved to vision.csv
# resnext50_32x4d: 0.001820
# Experiment results saved to vision.csv
# resnext50_32x4d: 0.001865
# Experiment results saved to vision.csv
# resnext50_32x4d: 0.001820
# Experiment results saved to vision.csv
# resnext50_32x4d: 0.001791
# Experiment results saved to vision.csv
# resnext50_32x4d: 0.001737
# Experiment results saved to vision.csv
# resnext50_32x4d: 0.001804
# Experiment results saved to vision.csv
# resnext50_32x4d: 0.001703
# Experiment results saved to vision.csv
# resnext101_32x8d: 0.001862
# Experiment results saved to vision.csv
# resnext101_32x8d: 0.001894
# Experiment results saved to vision.csv
# resnext101_32x8d: 0.001761
# Experiment results saved to vision.csv
# resnext101_32x8d: 0.001833
# Experiment results saved to vision.csv
# resnext101_32x8d: 0.001823
# Experiment results saved to vision.csv
# resnext101_32x8d: 0.001833
# Experiment results saved to vision.csv
# resnext101_32x8d: 0.001905
# Experiment results saved to vision.csv
# resnext101_32x8d: 0.001853
# Experiment results saved to vision.csv
# resnext101_32x8d: 0.001801
# Experiment results saved to vision.csv
# resnext101_32x8d: 0.001863
# Experiment results saved to vision.csv
# resnext101_64x4d: 0.001923
# Experiment results saved to vision.csv
# resnext101_64x4d: 0.001761
# Experiment results saved to vision.csv
# resnext101_64x4d: 0.001739
# Experiment results saved to vision.csv
# resnext101_64x4d: 0.001904
# Experiment results saved to vision.csv
# resnext101_64x4d: 0.001779
# Experiment results saved to vision.csv
# resnext101_64x4d: 0.001761
# Experiment results saved to vision.csv
# resnext101_64x4d: 0.001864
# Experiment results saved to vision.csv
# resnext101_64x4d: 0.001843
# Experiment results saved to vision.csv
# resnext101_64x4d: 0.001832
# Experiment results saved to vision.csv
# resnext101_64x4d: 0.001761
# Experiment results saved to vision.csv
# squeezenet1_0: 0.001680
# Experiment results saved to vision.csv
# squeezenet1_0: 0.001598
# Experiment results saved to vision.csv
# squeezenet1_0: 0.001660
# Experiment results saved to vision.csv
# squeezenet1_0: 0.001630
# Experiment results saved to vision.csv
# squeezenet1_0: 0.001721
# Experiment results saved to vision.csv
# squeezenet1_0: 0.001600
# Experiment results saved to vision.csv
# squeezenet1_0: 0.001790
# Experiment results saved to vision.csv
# squeezenet1_0: 0.001629
# Experiment results saved to vision.csv
# squeezenet1_0: 0.001714
# Experiment results saved to vision.csv
# squeezenet1_0: 0.001650
# Experiment results saved to vision.csv
# squeezenet1_1: 0.001686
# Experiment results saved to vision.csv
# squeezenet1_1: 0.001686
# Experiment results saved to vision.csv
# squeezenet1_1: 0.001655
# Experiment results saved to vision.csv
# squeezenet1_1: 0.001662
# Experiment results saved to vision.csv
# squeezenet1_1: 0.001648
# Experiment results saved to vision.csv
# squeezenet1_1: 0.001628
# Experiment results saved to vision.csv
# squeezenet1_1: 0.001605
# Experiment results saved to vision.csv
# squeezenet1_1: 0.001635
# Experiment results saved to vision.csv
# squeezenet1_1: 0.001688
# Experiment results saved to vision.csv
# squeezenet1_1: 0.001632
# Experiment results saved to vision.csv

# %% [markdown]
# * gpu

# %%
for model in model_list:
    for i in range(10):
        ! python measure_vismodel_latency.py --hardware pc --device gpu --dataset uci --arch $model --num-runs 100 --config_file vision.csv
# Out:
# mobilenet_v2: 4.537428
# Experiment results saved to vision.csv
# mobilenet_v2: 4.431942
# Experiment results saved to vision.csv
# mobilenet_v2: 4.530509
# Experiment results saved to vision.csv
# mobilenet_v2: 4.669222
# Experiment results saved to vision.csv
# mobilenet_v2: 4.467535
# Experiment results saved to vision.csv
# mobilenet_v2: 4.619354
# Experiment results saved to vision.csv
# mobilenet_v2: 4.466136
# Experiment results saved to vision.csv
# mobilenet_v2: 4.566924
# Experiment results saved to vision.csv
# mobilenet_v2: 4.581196
# Experiment results saved to vision.csv
# mobilenet_v2: 4.775070
# Experiment results saved to vision.csv
# mobilenet_v3_small: 5.116216
# Experiment results saved to vision.csv
# mobilenet_v3_small: 4.889116
# Experiment results saved to vision.csv
# mobilenet_v3_small: 4.952071
# Experiment results saved to vision.csv
# mobilenet_v3_small: 4.880513
# Experiment results saved to vision.csv
# mobilenet_v3_small: 5.198453
# Experiment results saved to vision.csv
# mobilenet_v3_small: 4.836390
# Experiment results saved to vision.csv
# mobilenet_v3_small: 4.893142
# Experiment results saved to vision.csv
# mobilenet_v3_small: 4.751515
# Experiment results saved to vision.csv
# mobilenet_v3_small: 4.871241
# Experiment results saved to vision.csv
# mobilenet_v3_small: 4.857634
# Experiment results saved to vision.csv
# mobilenet_v3_large: 5.484487
# Experiment results saved to vision.csv
# mobilenet_v3_large: 5.460295
# Experiment results saved to vision.csv
# mobilenet_v3_large: 5.542273
# Experiment results saved to vision.csv
# mobilenet_v3_large: 5.661226
# Experiment results saved to vision.csv
# mobilenet_v3_large: 5.487624
# Experiment results saved to vision.csv
# mobilenet_v3_large: 5.527900
# Experiment results saved to vision.csv
# mobilenet_v3_large: 5.747174
# Experiment results saved to vision.csv
# mobilenet_v3_large: 5.670347
# Experiment results saved to vision.csv
# mobilenet_v3_large: 5.705138
# Experiment results saved to vision.csv
# mobilenet_v3_large: 5.721273
# Experiment results saved to vision.csv
# mnasnet0_5: 4.309013
# Experiment results saved to vision.csv
# mnasnet0_5: 4.292652
# Experiment results saved to vision.csv
# mnasnet0_5: 4.219447
# Experiment results saved to vision.csv
# mnasnet0_5: 4.341005
# Experiment results saved to vision.csv
# mnasnet0_5: 4.306099
# Experiment results saved to vision.csv
# mnasnet0_5: 4.295022
# Experiment results saved to vision.csv
# mnasnet0_5: 4.343400
# Experiment results saved to vision.csv
# mnasnet0_5: 4.323024
# Experiment results saved to vision.csv
# mnasnet0_5: 4.322437
# Experiment results saved to vision.csv
# mnasnet0_5: 4.235125
# Experiment results saved to vision.csv
# mnasnet0_75: 4.271754
# Experiment results saved to vision.csv
# mnasnet0_75: 4.366449
# Experiment results saved to vision.csv
# mnasnet0_75: 4.276085
# Experiment results saved to vision.csv
# mnasnet0_75: 4.477126
# Experiment results saved to vision.csv
# mnasnet0_75: 4.329927
# Experiment results saved to vision.csv
# mnasnet0_75: 4.479276
# Experiment results saved to vision.csv
# mnasnet0_75: 4.263953
# Experiment results saved to vision.csv
# mnasnet0_75: 4.361863
# Experiment results saved to vision.csv
# mnasnet0_75: 4.298815
# Experiment results saved to vision.csv
# mnasnet0_75: 4.426289
# Experiment results saved to vision.csv
# mnasnet1_0: 4.361881
# Experiment results saved to vision.csv
# mnasnet1_0: 4.519140
# Experiment results saved to vision.csv
# mnasnet1_0: 4.488731
# Experiment results saved to vision.csv
# mnasnet1_0: 4.457188
# Experiment results saved to vision.csv
# mnasnet1_0: 4.353937
# Experiment results saved to vision.csv
# mnasnet1_0: 4.391475
# Experiment results saved to vision.csv
# mnasnet1_0: 4.536871
# Experiment results saved to vision.csv
# mnasnet1_0: 4.404387
# Experiment results saved to vision.csv
# mnasnet1_0: 4.377889
# Experiment results saved to vision.csv
# mnasnet1_0: 4.333806
# Experiment results saved to vision.csv
# mnasnet1_3: 4.391330
# Experiment results saved to vision.csv
# mnasnet1_3: 4.405767
# Experiment results saved to vision.csv
# mnasnet1_3: 4.482481
# Experiment results saved to vision.csv
# mnasnet1_3: 4.396568
# Experiment results saved to vision.csv
# mnasnet1_3: 4.382406
# Experiment results saved to vision.csv
# mnasnet1_3: 4.635656
# Experiment results saved to vision.csv
# mnasnet1_3: 4.496412
# Experiment results saved to vision.csv
# mnasnet1_3: 4.500323
# Experiment results saved to vision.csv
# mnasnet1_3: 4.454091
# Experiment results saved to vision.csv
# mnasnet1_3: 4.482714
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 5.253358
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 5.551471
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 5.435740
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 5.473435
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 5.341323
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 5.400272
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 5.280796
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 5.362862
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 5.250445
# Experiment results saved to vision.csv
# shufflenet_v2_x0_5: 5.388695
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 5.337495
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 5.533827
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 5.410745
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 5.530796
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 5.379077
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 5.407502
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 5.241933
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 5.399487
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 5.347358
# Experiment results saved to vision.csv
# shufflenet_v2_x1_0: 5.354855
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 5.432280
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 5.472310
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 5.430371
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 5.643273
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 5.520755
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 5.391612
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 5.368633
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 5.453374
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 5.397552
# Experiment results saved to vision.csv
# shufflenet_v2_x1_5: 5.586183
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 5.619500
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 5.436069
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 5.539131
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 5.383556
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 5.515874
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 5.347520
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 5.507956
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 5.719283
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 5.449459
# Experiment results saved to vision.csv
# shufflenet_v2_x2_0: 5.421017
# Experiment results saved to vision.csv
# resnet18: 2.764860
# Experiment results saved to vision.csv
# resnet18: 2.747589
# Experiment results saved to vision.csv
# resnet18: 2.798383
# Experiment results saved to vision.csv
# resnet18: 2.750069
# Experiment results saved to vision.csv
# resnet18: 2.772761
# Experiment results saved to vision.csv
# resnet18: 2.779697
# Experiment results saved to vision.csv
# resnet18: 2.806074
# Experiment results saved to vision.csv
# resnet18: 2.765020
# Experiment results saved to vision.csv
# resnet18: 2.807963
# Experiment results saved to vision.csv
# resnet18: 2.749660
# Experiment results saved to vision.csv
# resnet34: 5.368007
# Experiment results saved to vision.csv
# resnet34: 5.231755
# Experiment results saved to vision.csv
# resnet34: 5.304975
# Experiment results saved to vision.csv
# resnet34: 5.244671
# Experiment results saved to vision.csv
# resnet34: 5.254440
# Experiment results saved to vision.csv
# resnet34: 5.490437
# Experiment results saved to vision.csv
# resnet34: 5.234777
# Experiment results saved to vision.csv
# resnet34: 5.370413
# Experiment results saved to vision.csv
# resnet34: 5.214316
# Experiment results saved to vision.csv
# resnet34: 5.518371
# Experiment results saved to vision.csv
# resnet50: 5.261493
# Experiment results saved to vision.csv
# resnet50: 5.363387
# Experiment results saved to vision.csv
# resnet50: 5.291317
# Experiment results saved to vision.csv
# resnet50: 5.349531
# Experiment results saved to vision.csv
# resnet50: 5.275479
# Experiment results saved to vision.csv
# resnet50: 5.446980
# Experiment results saved to vision.csv
# resnet50: 5.462078
# Experiment results saved to vision.csv
# resnet50: 5.396556
# Experiment results saved to vision.csv
# resnet50: 5.371948
# Experiment results saved to vision.csv
# resnet50: 5.346293
# Experiment results saved to vision.csv
# resnet101: 13.061558
# Experiment results saved to vision.csv
# resnet101: 13.318201
# Experiment results saved to vision.csv
# resnet101: 13.293095
# Experiment results saved to vision.csv
# resnet101: 13.230039
# Experiment results saved to vision.csv
# resnet101: 13.332839
# Experiment results saved to vision.csv
# resnet101: 13.051763
# Experiment results saved to vision.csv
# resnet101: 13.191478
# Experiment results saved to vision.csv
# resnet101: 13.235675
# Experiment results saved to vision.csv
# resnet101: 13.169715
# Experiment results saved to vision.csv
# resnet101: 13.137924
# Experiment results saved to vision.csv
# resnext50_32x4d: 5.505597
# Experiment results saved to vision.csv
# resnext50_32x4d: 5.628215
# Experiment results saved to vision.csv
# resnext50_32x4d: 5.543654
# Experiment results saved to vision.csv
# resnext50_32x4d: 5.596017
# Experiment results saved to vision.csv
# resnext50_32x4d: 5.921363
# Experiment results saved to vision.csv
# resnext50_32x4d: 5.591662
# Experiment results saved to vision.csv
# resnext50_32x4d: 5.427270
# Experiment results saved to vision.csv
# resnext50_32x4d: 5.490448
# Experiment results saved to vision.csv
# resnext50_32x4d: 5.651580
# Experiment results saved to vision.csv
# resnext50_32x4d: 5.461871
# Experiment results saved to vision.csv
# resnext101_32x8d: 13.401748
# Experiment results saved to vision.csv
# resnext101_32x8d: 13.499312
# Experiment results saved to vision.csv
# resnext101_32x8d: 13.559145
# Experiment results saved to vision.csv
# resnext101_32x8d: 13.393542
# Experiment results saved to vision.csv
# resnext101_32x8d: 14.010694
# Experiment results saved to vision.csv
# resnext101_32x8d: 15.245252
# Experiment results saved to vision.csv
# resnext101_32x8d: 13.178766
# Experiment results saved to vision.csv
# resnext101_32x8d: 13.194901
# Experiment results saved to vision.csv
# resnext101_32x8d: 13.560607
# Experiment results saved to vision.csv
# resnext101_32x8d: 13.049955
# Experiment results saved to vision.csv
# resnext101_64x4d: 12.235214
# Experiment results saved to vision.csv
# resnext101_64x4d: 11.044479
# Experiment results saved to vision.csv
# resnext101_64x4d: 11.070422
# Experiment results saved to vision.csv
# resnext101_64x4d: 11.215939
# Experiment results saved to vision.csv
# resnext101_64x4d: 11.276838
# Experiment results saved to vision.csv
# resnext101_64x4d: 11.217557
# Experiment results saved to vision.csv
# resnext101_64x4d: 11.042829
# Experiment results saved to vision.csv
# resnext101_64x4d: 11.295256
# Experiment results saved to vision.csv
# resnext101_64x4d: 11.303326
# Experiment results saved to vision.csv
# resnext101_64x4d: 11.040720
# Experiment results saved to vision.csv
# squeezenet1_0: 2.437958
# Experiment results saved to vision.csv
# squeezenet1_0: 2.436605
# Experiment results saved to vision.csv
# squeezenet1_0: 2.427317
# Experiment results saved to vision.csv
# squeezenet1_0: 2.512064
# Experiment results saved to vision.csv
# squeezenet1_0: 2.444961
# Experiment results saved to vision.csv
# squeezenet1_0: 2.414215
# Experiment results saved to vision.csv
# squeezenet1_0: 2.509558
# Experiment results saved to vision.csv
# squeezenet1_0: 2.382557
# Experiment results saved to vision.csv
# squeezenet1_0: 2.436578
# Experiment results saved to vision.csv
# squeezenet1_0: 2.442231
# Experiment results saved to vision.csv
# squeezenet1_1: 2.399313
# Experiment results saved to vision.csv
# squeezenet1_1: 2.446414
# Experiment results saved to vision.csv
# squeezenet1_1: 2.460295
# Experiment results saved to vision.csv
# squeezenet1_1: 2.441285
# Experiment results saved to vision.csv
# squeezenet1_1: 2.407664
# Experiment results saved to vision.csv
# squeezenet1_1: 2.424975
# Experiment results saved to vision.csv
# squeezenet1_1: 2.367320
# Experiment results saved to vision.csv
# squeezenet1_1: 2.477246
# Experiment results saved to vision.csv
# squeezenet1_1: 2.414298
# Experiment results saved to vision.csv
# squeezenet1_1: 2.526510
# Experiment results saved to vision.csv

# %% [markdown]
# ## EfficientNet

# %%
# 나머지 모델들
model_list = [
    "efficientnet_b0",
    "efficientnet_b1",
    "efficientnet_b2",
    "efficientnet_b3",
    "efficientnet_b4",
    "efficientnet_b5",
    "efficientnet_b6",
    "efficientnet_b7",
    "efficientnet_v2_s",
    "efficientnet_v2_m",
    "efficientnet_v2_l",]

# %% [markdown]
# * cpu

# %%
for model in model_list:
    for i in range(10):
        ! python measure_vismodel_latency.py --hardware pc --device cpu --dataset uci --arch $model --num-runs 100 --config_file vision.csv
# Out:
# efficientnet_b0: 0.001844
# Experiment results saved to vision.csv
# efficientnet_b0: 0.001806
# Experiment results saved to vision.csv
# efficientnet_b0: 0.001688
# Experiment results saved to vision.csv
# efficientnet_b0: 0.001736
# Experiment results saved to vision.csv
# efficientnet_b0: 0.001764
# Experiment results saved to vision.csv
# efficientnet_b0: 0.001779
# Experiment results saved to vision.csv
# efficientnet_b0: 0.001704
# Experiment results saved to vision.csv
# efficientnet_b0: 0.001721
# Experiment results saved to vision.csv
# efficientnet_b0: 0.001756
# Experiment results saved to vision.csv
# efficientnet_b0: 0.001715
# Experiment results saved to vision.csv
# efficientnet_b1: 0.001763
# Experiment results saved to vision.csv
# efficientnet_b1: 0.001773
# Experiment results saved to vision.csv
# efficientnet_b1: 0.001787
# Experiment results saved to vision.csv
# efficientnet_b1: 0.001694
# Experiment results saved to vision.csv
# efficientnet_b1: 0.001785
# Experiment results saved to vision.csv
# efficientnet_b1: 0.001716
# Experiment results saved to vision.csv
# efficientnet_b1: 0.001733
# Experiment results saved to vision.csv
# efficientnet_b1: 0.001809
# Experiment results saved to vision.csv
# efficientnet_b1: 0.001904
# Experiment results saved to vision.csv
# efficientnet_b1: 0.001867
# Experiment results saved to vision.csv
# efficientnet_b2: 0.001795
# Experiment results saved to vision.csv
# efficientnet_b2: 0.001836
# Experiment results saved to vision.csv
# efficientnet_b2: 0.001665
# Experiment results saved to vision.csv
# efficientnet_b2: 0.001871
# Experiment results saved to vision.csv
# efficientnet_b2: 0.001827
# Experiment results saved to vision.csv
# efficientnet_b2: 0.001798
# Experiment results saved to vision.csv
# efficientnet_b2: 0.001869
# Experiment results saved to vision.csv
# efficientnet_b2: 0.001764
# Experiment results saved to vision.csv
# efficientnet_b2: 0.001781
# Experiment results saved to vision.csv
# efficientnet_b2: 0.001769
# Experiment results saved to vision.csv
# efficientnet_b3: 0.001851
# Experiment results saved to vision.csv
# efficientnet_b3: 0.001864
# Experiment results saved to vision.csv
# efficientnet_b3: 0.001831
# Experiment results saved to vision.csv
# efficientnet_b3: 0.001727
# Experiment results saved to vision.csv
# efficientnet_b3: 0.001788
# Experiment results saved to vision.csv
# efficientnet_b3: 0.001831
# Experiment results saved to vision.csv
# efficientnet_b3: 0.001764
# Experiment results saved to vision.csv
# efficientnet_b3: 0.001676
# Experiment results saved to vision.csv
# efficientnet_b3: 0.001718
# Experiment results saved to vision.csv
# efficientnet_b3: 0.001831
# Experiment results saved to vision.csv
# efficientnet_b4: 0.001821
# Experiment results saved to vision.csv
# efficientnet_b4: 0.001913
# Experiment results saved to vision.csv
# efficientnet_b4: 0.001751
# Experiment results saved to vision.csv
# efficientnet_b4: 0.001800
# Experiment results saved to vision.csv
# efficientnet_b4: 0.001832
# Experiment results saved to vision.csv
# efficientnet_b4: 0.001820
# Experiment results saved to vision.csv
# efficientnet_b4: 0.001914
# Experiment results saved to vision.csv
# efficientnet_b4: 0.001823
# Experiment results saved to vision.csv
# efficientnet_b4: 0.001853
# Experiment results saved to vision.csv
# efficientnet_b4: 0.001760
# Experiment results saved to vision.csv
# efficientnet_b5: 0.001833
# Experiment results saved to vision.csv
# efficientnet_b5: 0.001833
# Experiment results saved to vision.csv
# efficientnet_b5: 0.001833
# Experiment results saved to vision.csv
# efficientnet_b5: 0.001740
# Experiment results saved to vision.csv
# efficientnet_b5: 0.001769
# Experiment results saved to vision.csv
# efficientnet_b5: 0.001853
# Experiment results saved to vision.csv
# efficientnet_b5: 0.001884
# Experiment results saved to vision.csv
# efficientnet_b5: 0.001923
# Experiment results saved to vision.csv
# efficientnet_b5: 0.001801
# Experiment results saved to vision.csv
# efficientnet_b5: 0.001810
# Experiment results saved to vision.csv
# efficientnet_b6: 0.001802
# Experiment results saved to vision.csv
# efficientnet_b6: 0.001810
# Experiment results saved to vision.csv
# efficientnet_b6: 0.001842
# Experiment results saved to vision.csv
# efficientnet_b6: 0.001812
# Experiment results saved to vision.csv
# efficientnet_b6: 0.001799
# Experiment results saved to vision.csv
# efficientnet_b6: 0.001823
# Experiment results saved to vision.csv
# efficientnet_b6: 0.001808
# Experiment results saved to vision.csv
# efficientnet_b6: 0.001841
# Experiment results saved to vision.csv
# efficientnet_b6: 0.001831
# Experiment results saved to vision.csv
# efficientnet_b6: 0.001812
# Experiment results saved to vision.csv
# efficientnet_b7: 0.001853
# Experiment results saved to vision.csv
# efficientnet_b7: 0.001864
# Experiment results saved to vision.csv
# efficientnet_b7: 0.001812
# Experiment results saved to vision.csv
# efficientnet_b7: 0.001863
# Experiment results saved to vision.csv
# efficientnet_b7: 0.001852
# Experiment results saved to vision.csv
# efficientnet_b7: 0.001872
# Experiment results saved to vision.csv
# efficientnet_b7: 0.001833
# Experiment results saved to vision.csv
# efficientnet_b7: 0.001915
# Experiment results saved to vision.csv
# efficientnet_b7: 0.001956
# Experiment results saved to vision.csv
# efficientnet_b7: 0.001884
# Experiment results saved to vision.csv
# efficientnet_v2_s: 0.001822
# Experiment results saved to vision.csv
# efficientnet_v2_s: 0.001852
# Experiment results saved to vision.csv
# efficientnet_v2_s: 0.001894
# Experiment results saved to vision.csv
# efficientnet_v2_s: 0.001812
# Experiment results saved to vision.csv
# efficientnet_v2_s: 0.001976
# Experiment results saved to vision.csv
# efficientnet_v2_s: 0.001843
# Experiment results saved to vision.csv
# efficientnet_v2_s: 0.001933
# Experiment results saved to vision.csv
# efficientnet_v2_s: 0.001833
# Experiment results saved to vision.csv
# efficientnet_v2_s: 0.001759
# Experiment results saved to vision.csv
# efficientnet_v2_s: 0.001843
# Experiment results saved to vision.csv
# efficientnet_v2_m: 0.001884
# Experiment results saved to vision.csv
# efficientnet_v2_m: 0.001864
# Experiment results saved to vision.csv
# efficientnet_v2_m: 0.001710
# Experiment results saved to vision.csv
# efficientnet_v2_m: 0.001863
# Experiment results saved to vision.csv
# efficientnet_v2_m: 0.001831
# Experiment results saved to vision.csv
# efficientnet_v2_m: 0.001975
# Experiment results saved to vision.csv
# efficientnet_v2_m: 0.001822
# Experiment results saved to vision.csv
# efficientnet_v2_m: 0.001820
# Experiment results saved to vision.csv
# efficientnet_v2_m: 0.001821
# Experiment results saved to vision.csv
# efficientnet_v2_m: 0.001884
# Experiment results saved to vision.csv
# efficientnet_v2_l: 0.001872
# Experiment results saved to vision.csv
# efficientnet_v2_l: 0.001874
# Experiment results saved to vision.csv
# efficientnet_v2_l: 0.001894
# Experiment results saved to vision.csv
# efficientnet_v2_l: 0.001853
# Experiment results saved to vision.csv
# efficientnet_v2_l: 0.001749
# Experiment results saved to vision.csv
# efficientnet_v2_l: 0.001821
# Experiment results saved to vision.csv
# efficientnet_v2_l: 0.001874
# Experiment results saved to vision.csv
# efficientnet_v2_l: 0.001779
# Experiment results saved to vision.csv
# efficientnet_v2_l: 0.001873
# Experiment results saved to vision.csv
# efficientnet_v2_l: 0.001894
# Experiment results saved to vision.csv

# %% [markdown]
# * gpu

# %%
for model in model_list:
    for i in range(10):
        ! python measure_vismodel_latency.py --hardware pc --device gpu --dataset uci --arch $model --num-runs 100 --config_file vision.csv
# Out:
# efficientnet_b0: 7.878760
# Experiment results saved to vision.csv
# efficientnet_b0: 7.865538
# Experiment results saved to vision.csv
# efficientnet_b0: 7.939623
# Experiment results saved to vision.csv
# efficientnet_b0: 7.671827
# Experiment results saved to vision.csv
# efficientnet_b0: 8.148652
# Experiment results saved to vision.csv
# efficientnet_b0: 7.912564
# Experiment results saved to vision.csv
# efficientnet_b0: 7.639405
# Experiment results saved to vision.csv
# efficientnet_b0: 7.787745
# Experiment results saved to vision.csv
# efficientnet_b0: 7.753617
# Experiment results saved to vision.csv
# efficientnet_b0: 7.747763
# Experiment results saved to vision.csv
# efficientnet_b1: 11.530394
# Experiment results saved to vision.csv
# efficientnet_b1: 11.095603
# Experiment results saved to vision.csv
# efficientnet_b1: 11.282107
# Experiment results saved to vision.csv
# Traceback (most recent call last):
#   File "d:\Develop\3.Research\2022-\0.My_Code\3.harnas\measure_vismodel_latency.py", line 16, in <module>
#     from models.vision import *
#   File "d:\Develop\3.Research\2022-\0.My_Code\3.harnas\models\__init__.py", line 3
#     from .rnns import HARLSTM, HARBiLSTM, HARConvLSTM, ,
#                                                        ^
# SyntaxError: invalid syntax
# efficientnet_b1: 12.255544
# Experiment results saved to vision.csv
# efficientnet_b1: 10.969066
# Experiment results saved to vision.csv
# efficientnet_b1: 11.204213
# Experiment results saved to vision.csv
# efficientnet_b1: 10.975613
# Experiment results saved to vision.csv
# efficientnet_b1: 11.463412
# Experiment results saved to vision.csv
# efficientnet_b1: 11.220981
# Experiment results saved to vision.csv
# efficientnet_b2: 11.593362
# Experiment results saved to vision.csv
# efficientnet_b2: 10.870232
# Experiment results saved to vision.csv
# efficientnet_b2: 11.430872
# Experiment results saved to vision.csv
# efficientnet_b2: 11.372756
# Experiment results saved to vision.csv
# efficientnet_b2: 11.028010
# Experiment results saved to vision.csv
# efficientnet_b2: 10.759300
# Experiment results saved to vision.csv
# efficientnet_b2: 11.184759
# Experiment results saved to vision.csv
# efficientnet_b2: 11.031055
# Experiment results saved to vision.csv
# efficientnet_b2: 11.045985
# Experiment results saved to vision.csv
# efficientnet_b2: 11.040473
# Experiment results saved to vision.csv
# efficientnet_b3: 12.650784
# Experiment results saved to vision.csv
# efficientnet_b3: 13.201944
# Experiment results saved to vision.csv
# efficientnet_b3: 12.787206
# Experiment results saved to vision.csv
# efficientnet_b3: 13.277470
# Experiment results saved to vision.csv
# efficientnet_b3: 12.509656
# Experiment results saved to vision.csv
# efficientnet_b3: 12.690177
# Experiment results saved to vision.csv
# efficientnet_b3: 12.690358
# Experiment results saved to vision.csv
# efficientnet_b3: 12.545745
# Experiment results saved to vision.csv
# efficientnet_b3: 12.920341
# Experiment results saved to vision.csv
# efficientnet_b3: 12.607157
# Experiment results saved to vision.csv
# efficientnet_b4: 15.618279
# Experiment results saved to vision.csv
# efficientnet_b4: 15.781967
# Experiment results saved to vision.csv
# efficientnet_b4: 15.724191
# Experiment results saved to vision.csv
# efficientnet_b4: 15.794984
# Experiment results saved to vision.csv
# efficientnet_b4: 15.456744
# Experiment results saved to vision.csv
# efficientnet_b4: 15.672016
# Experiment results saved to vision.csv
# efficientnet_b4: 16.283010
# Experiment results saved to vision.csv
# efficientnet_b4: 16.873106
# Experiment results saved to vision.csv
# efficientnet_b4: 16.111523
# Experiment results saved to vision.csv
# efficientnet_b4: 15.573712
# Experiment results saved to vision.csv
# efficientnet_b5: 19.749540
# Experiment results saved to vision.csv
# efficientnet_b5: 19.357147
# Experiment results saved to vision.csv
# efficientnet_b5: 19.546196
# Experiment results saved to vision.csv
# efficientnet_b5: 19.609172
# Experiment results saved to vision.csv
# efficientnet_b5: 19.258063
# Experiment results saved to vision.csv
# efficientnet_b5: 19.548779
# Experiment results saved to vision.csv
# efficientnet_b5: 19.452467
# Experiment results saved to vision.csv
# efficientnet_b5: 19.726274
# Experiment results saved to vision.csv
# efficientnet_b5: 20.337601
# Experiment results saved to vision.csv
# efficientnet_b5: 19.170995
# Experiment results saved to vision.csv
# efficientnet_b6: 22.445631
# Experiment results saved to vision.csv
# efficientnet_b6: 22.238493
# Experiment results saved to vision.csv
# efficientnet_b6: 23.437272
# Experiment results saved to vision.csv
# efficientnet_b6: 22.675766
# Experiment results saved to vision.csv
# efficientnet_b6: 22.839324
# Experiment results saved to vision.csv
# efficientnet_b6: 23.350098
# Experiment results saved to vision.csv
# efficientnet_b6: 22.573092
# Experiment results saved to vision.csv
# efficientnet_b6: 22.893772
# Experiment results saved to vision.csv
# efficientnet_b6: 22.306658
# Experiment results saved to vision.csv
# efficientnet_b6: 22.285349
# Experiment results saved to vision.csv
# efficientnet_b7: 27.354441
# Experiment results saved to vision.csv
# efficientnet_b7: 27.348988
# Experiment results saved to vision.csv
# efficientnet_b7: 27.168549
# Experiment results saved to vision.csv
# efficientnet_b7: 27.923328
# Experiment results saved to vision.csv
# efficientnet_b7: 28.646170
# Experiment results saved to vision.csv
# efficientnet_b7: 28.052613
# Experiment results saved to vision.csv
# efficientnet_b7: 27.992213
# Experiment results saved to vision.csv
# efficientnet_b7: 28.028960
# Experiment results saved to vision.csv
# efficientnet_b7: 27.851514
# Experiment results saved to vision.csv
# efficientnet_b7: 27.809005
# Experiment results saved to vision.csv
# efficientnet_v2_s: 17.592016
# Experiment results saved to vision.csv
# efficientnet_v2_s: 17.775799
# Experiment results saved to vision.csv
# efficientnet_v2_s: 17.426662
# Experiment results saved to vision.csv
# efficientnet_v2_s: 17.833183
# Experiment results saved to vision.csv
# efficientnet_v2_s: 17.541895
# Experiment results saved to vision.csv
# efficientnet_v2_s: 17.504353
# Experiment results saved to vision.csv
# efficientnet_v2_s: 18.222594
# Experiment results saved to vision.csv
# efficientnet_v2_s: 18.227335
# Experiment results saved to vision.csv
# efficientnet_v2_s: 18.146878
# Experiment results saved to vision.csv
# efficientnet_v2_s: 17.760893
# Experiment results saved to vision.csv
# efficientnet_v2_m: 25.330155
# Experiment results saved to vision.csv
# efficientnet_v2_m: 25.390492
# Experiment results saved to vision.csv
# efficientnet_v2_m: 25.324010
# Experiment results saved to vision.csv
# efficientnet_v2_m: 25.950962
# Experiment results saved to vision.csv
# efficientnet_v2_m: 26.155104
# Experiment results saved to vision.csv
# efficientnet_v2_m: 25.667360
# Experiment results saved to vision.csv
# efficientnet_v2_m: 25.528627
# Experiment results saved to vision.csv
# efficientnet_v2_m: 25.753910
# Experiment results saved to vision.csv
# efficientnet_v2_m: 25.432892
# Experiment results saved to vision.csv
# efficientnet_v2_m: 25.101524
# Experiment results saved to vision.csv
# efficientnet_v2_l: 36.924135
# Experiment results saved to vision.csv
# efficientnet_v2_l: 35.799193
# Experiment results saved to vision.csv
# efficientnet_v2_l: 35.190819
# Experiment results saved to vision.csv
# efficientnet_v2_l: 35.515561
# Experiment results saved to vision.csv
# efficientnet_v2_l: 35.968858
# Experiment results saved to vision.csv
# efficientnet_v2_l: 36.129703
# Experiment results saved to vision.csv
# efficientnet_v2_l: 35.856402
# Experiment results saved to vision.csv
# efficientnet_v2_l: 36.431472
# Experiment results saved to vision.csv
# efficientnet_v2_l: 36.528715
# Experiment results saved to vision.csv
# efficientnet_v2_l: 35.598300
# Experiment results saved to vision.csv

# %% [markdown]
# ## Model Spec

# %%
model_list = ["mobilenet_v2", "mobilenet_v3_small", "mobilenet_v3_large", "mnasnet0_5", "mnasnet0_75", "mnasnet1_0", "mnasnet1_3", "shufflenet_v2_x0_5", "shufflenet_v2_x1_0", "shufflenet_v2_x1_5", "shufflenet_v2_x2_0", "resnet18", "resnet34", "resnet50", "resnet101", "resnext50_32x4d", "resnext101_32x8d", "resnext101_64x4d", "squeezenet1_0", "squeezenet1_1", "efficientnet_b0", "efficientnet_b1", "efficientnet_b2", "efficientnet_b3", "efficientnet_b4", "efficientnet_b5", "efficientnet_b6", "efficientnet_b7", "efficientnet_v2_s", "efficientnet_v2_m", "efficientnet_v2_l"]

# %%
for model in model_list:
    ! python measure_vismodel_metrics.py --dataset uci --arch $model --config_file model_spec.csv
# Out:
# Flops: 11872768.000000, Param size: 2188454.000000MB
# Flops: 12.144896, Param size: 2.188454MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::hardtanh_ encountered 35 time(s)
# Unsupported operator aten::add encountered 10 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 1 time(s)
# Flops: 3264320.000000, Param size: 1477206.000000MB
# Flops: 3.364792, Param size: 1.477206MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::hardswish_ encountered 19 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 10 time(s)
# Unsupported operator aten::hardsigmoid encountered 9 time(s)
# Unsupported operator aten::mul encountered 9 time(s)
# Unsupported operator aten::add_ encountered 6 time(s)
# Unsupported operator aten::dropout_ encountered 1 time(s)
# Flops: 10822720.000000, Param size: 4138822.000000MB
# Flops: 11.046616, Param size: 4.138822MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::hardswish_ encountered 21 time(s)
# Unsupported operator aten::add_ encountered 10 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 9 time(s)
# Unsupported operator aten::hardsigmoid encountered 8 time(s)
# Unsupported operator aten::mul encountered 8 time(s)
# Unsupported operator aten::dropout_ encountered 1 time(s)
# Flops: 4323840.000000, Param size: 880974.000000MB
# Flops: 4.466048, Param size: 0.880974MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::add encountered 10 time(s)
# Unsupported operator aten::mean encountered 1 time(s)
# Unsupported operator aten::dropout_ encountered 1 time(s)
# Flops: 8977344.000000, Param size: 1800342.000000MB
# Flops: 9.187776, Param size: 1.800342MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::add encountered 10 time(s)
# Unsupported operator aten::mean encountered 1 time(s)
# Unsupported operator aten::dropout_ encountered 1 time(s)
# Flops: 14555904.000000, Param size: 2984238.000000MB
# Flops: 14.813952, Param size: 2.984238MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::add encountered 10 time(s)
# Unsupported operator aten::mean encountered 1 time(s)
# Unsupported operator aten::dropout_ encountered 1 time(s)
# Flops: 23980032.000000, Param size: 4844518.000000MB
# Flops: 24.318848, Param size: 4.844518MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::add encountered 10 time(s)
# Unsupported operator aten::mean encountered 1 time(s)
# Unsupported operator aten::dropout_ encountered 1 time(s)
# Flops: 1689728.000000, Param size: 341534.000000MB
# Flops: 1.744768, Param size: 0.341534MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::max_pool1d encountered 1 time(s)
# Unsupported operator aten::mean encountered 1 time(s)
# The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# stage2.1.branch1, stage2.2.branch1, stage2.3.branch1, stage3.1.branch1, stage3.2.branch1, stage3.3.branch1, stage3.4.branch1, stage3.5.branch1, stage3.6.branch1, stage3.7.branch1, stage4.1.branch1, stage4.2.branch1, stage4.3.branch1
# Flops: 6635776.000000, Param size: 1244778.000000MB
# Flops: 6.751744, Param size: 1.244778MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::max_pool1d encountered 1 time(s)
# Unsupported operator aten::mean encountered 1 time(s)
# The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# stage2.1.branch1, stage2.2.branch1, stage2.3.branch1, stage3.1.branch1, stage3.2.branch1, stage3.3.branch1, stage3.4.branch1, stage3.5.branch1, stage3.6.branch1, stage3.7.branch1, stage4.1.branch1, stage4.2.branch1, stage4.3.branch1
# Flops: 13549696.000000, Param size: 2462238.000000MB
# Flops: 13.719424, Param size: 2.462238MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::max_pool1d encountered 1 time(s)
# Unsupported operator aten::mean encountered 1 time(s)
# The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# stage2.1.branch1, stage2.2.branch1, stage2.3.branch1, stage3.1.branch1, stage3.2.branch1, stage3.3.branch1, stage3.4.branch1, stage3.5.branch1, stage3.6.branch1, stage3.7.branch1, stage4.1.branch1, stage4.2.branch1, stage4.3.branch1
# Flops: 28287232.000000, Param size: 5326186.000000MB
# Flops: 28.526080, Param size: 5.326186MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::max_pool1d encountered 1 time(s)
# Unsupported operator aten::mean encountered 1 time(s)
# The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# stage2.1.branch1, stage2.2.branch1, stage2.3.branch1, stage3.1.branch1, stage3.2.branch1, stage3.3.branch1, stage3.4.branch1, stage3.5.branch1, stage3.6.branch1, stage3.7.branch1, stage4.1.branch1, stage4.2.branch1, stage4.3.branch1
# Flops: 22019072.000000, Param size: 3849222.000000MB
# Flops: 22.107648, Param size: 3.849222MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::max_pool1d encountered 1 time(s)
# Unsupported operator aten::add_ encountered 8 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 1 time(s)
# Flops: 44891136.000000, Param size: 7223558.000000MB
# Flops: 45.045248, Param size: 7.223558MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::max_pool1d encountered 1 time(s)
# Unsupported operator aten::add_ encountered 16 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 1 time(s)
# Flops: 44891136.000000, Param size: 7223558.000000MB
# Flops: 45.045248, Param size: 7.223558MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::max_pool1d encountered 1 time(s)
# Unsupported operator aten::add_ encountered 16 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 1 time(s)
# Flops: 199000064.000000, Param size: 28276230.000000MB
# Unsupported operator aten::max_pool1d encountered 1 time(s)
# Unsupported operator aten::add_ encountered 33 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 1 time(s)
# Flops: 199.907328, Param size: 28.276230MB
# Experiment results saved to model_spec.csv
# Flops: 141856768.000000, Param size: 22042374.000000MB
# Flops: 142.489600, Param size: 22.042374MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::max_pool1d encountered 1 time(s)
# Unsupported operator aten::add_ encountered 16 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 1 time(s)
# Flops: 573206528.000000, Param size: 79633158.000000MB
# Flops: 574.961664, Param size: 79.633158MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::max_pool1d encountered 1 time(s)
# Unsupported operator aten::add_ encountered 33 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 1 time(s)
# Flops: 560721920.000000, Param size: 77854470.000000MB
# Flops: 562.477056, Param size: 77.854470MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::max_pool1d encountered 1 time(s)
# Unsupported operator aten::add_ encountered 33 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 1 time(s)
# Flops: 5210304.000000, Param size: 359782.000000MB
# Flops: 5.210352, Param size: 0.359782MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::max_pool1d encountered 3 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 1 time(s)
# Flops: 3169152.000000, Param size: 356358.000000MB
# Flops: 3.169200, Param size: 0.356358MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::max_pool1d encountered 3 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 1 time(s)
# Flops: 17272320.000000, Param size: 3872482.000000MB
# Flops: 17.649408, Param size: 3.872482MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::silu_ encountered 49 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 17 time(s)
# Unsupported operator aten::sigmoid encountered 16 time(s)
# Unsupported operator aten::mul encountered 16 time(s)
# Unsupported operator aten::add_ encountered 9 time(s)
# Unsupported operator aten::dropout_ encountered 1 time(s)
# The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# features.1.0.stochastic_depth, features.2.0.stochastic_depth, features.2.1.stochastic_depth, features.3.0.stochastic_depth, features.3.1.stochastic_depth, features.4.0.stochastic_depth, features.4.1.stochastic_depth, features.4.2.stochastic_depth, features.5.0.stochastic_depth, features.5.1.stochastic_depth, features.5.2.stochastic_depth, features.6.0.stochastic_depth, features.6.1.stochastic_depth, features.6.2.stochastic_depth, features.6.3.stochastic_depth, features.7.0.stochastic_depth
# Flops: 27056128.000000, Param size: 6321478.000000MB
# Flops: 27.602704, Param size: 6.321478MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::silu_ encountered 69 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 24 time(s)
# Unsupported operator aten::sigmoid encountered 23 time(s)
# Unsupported operator aten::mul encountered 23 time(s)
# Unsupported operator aten::add_ encountered 16 time(s)
# Unsupported operator aten::dropout_ encountered 1 time(s)
# The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# features.1.0.stochastic_depth, features.1.1.stochastic_depth, features.2.0.stochastic_depth, features.2.1.stochastic_depth, features.2.2.stochastic_depth, features.3.0.stochastic_depth, features.3.1.stochastic_depth, features.3.2.stochastic_depth, features.4.0.stochastic_depth, features.4.1.stochastic_depth, features.4.2.stochastic_depth, features.4.3.stochastic_depth, features.5.0.stochastic_depth, features.5.1.stochastic_depth, features.5.2.stochastic_depth, features.5.3.stochastic_depth, features.6.0.stochastic_depth, features.6.1.stochastic_depth, features.6.2.stochastic_depth, features.6.3.stochastic_depth, features.6.4.stochastic_depth, features.7.0.stochastic_depth, features.7.1.stochastic_depth
# Flops: 32011008.000000, Param size: 7492776.000000MB
# Flops: 32.601984, Param size: 7.492776MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::silu_ encountered 69 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 24 time(s)
# Unsupported operator aten::sigmoid encountered 23 time(s)
# Unsupported operator aten::mul encountered 23 time(s)
# Unsupported operator aten::add_ encountered 16 time(s)
# Unsupported operator aten::dropout_ encountered 1 time(s)
# The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# features.1.0.stochastic_depth, features.1.1.stochastic_depth, features.2.0.stochastic_depth, features.2.1.stochastic_depth, features.2.2.stochastic_depth, features.3.0.stochastic_depth, features.3.1.stochastic_depth, features.3.2.stochastic_depth, features.4.0.stochastic_depth, features.4.1.stochastic_depth, features.4.2.stochastic_depth, features.4.3.stochastic_depth, features.5.0.stochastic_depth, features.5.1.stochastic_depth, features.5.2.stochastic_depth, features.5.3.stochastic_depth, features.6.0.stochastic_depth, features.6.1.stochastic_depth, features.6.2.stochastic_depth, features.6.3.stochastic_depth, features.6.4.stochastic_depth, features.7.0.stochastic_depth, features.7.1.stochastic_depth
# Flops: 45130880.000000, Param size: 10416134.000000MB
# Flops: 45.899392, Param size: 10.416134MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::silu_ encountered 78 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 27 time(s)
# Unsupported operator aten::sigmoid encountered 26 time(s)
# Unsupported operator aten::mul encountered 26 time(s)
# Unsupported operator aten::add_ encountered 19 time(s)
# Unsupported operator aten::dropout_ encountered 1 time(s)
# The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# features.1.0.stochastic_depth, features.1.1.stochastic_depth, features.2.0.stochastic_depth, features.2.1.stochastic_depth, features.2.2.stochastic_depth, features.3.0.stochastic_depth, features.3.1.stochastic_depth, features.3.2.stochastic_depth, features.4.0.stochastic_depth, features.4.1.stochastic_depth, features.4.2.stochastic_depth, features.4.3.stochastic_depth, features.4.4.stochastic_depth, features.5.0.stochastic_depth, features.5.1.stochastic_depth, features.5.2.stochastic_depth, features.5.3.stochastic_depth, features.5.4.stochastic_depth, features.6.0.stochastic_depth, features.6.1.stochastic_depth, features.6.2.stochastic_depth, features.6.3.stochastic_depth, features.6.4.stochastic_depth, features.6.5.stochastic_depth, features.7.0.stochastic_depth, features.7.1.stochastic_depth
# Flops: 73713888.000000, Param size: 17124974.000000MB
# Flops: 74.797624, Param size: 17.124974MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::silu_ encountered 96 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 33 time(s)
# Unsupported operator aten::sigmoid encountered 32 time(s)
# Unsupported operator aten::mul encountered 32 time(s)
# Unsupported operator aten::add_ encountered 25 time(s)
# Unsupported operator aten::dropout_ encountered 1 time(s)
# The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# features.1.0.stochastic_depth, features.1.1.stochastic_depth, features.2.0.stochastic_depth, features.2.1.stochastic_depth, features.2.2.stochastic_depth, features.2.3.stochastic_depth, features.3.0.stochastic_depth, features.3.1.stochastic_depth, features.3.2.stochastic_depth, features.3.3.stochastic_depth, features.4.0.stochastic_depth, features.4.1.stochastic_depth, features.4.2.stochastic_depth, features.4.3.stochastic_depth, features.4.4.stochastic_depth, features.4.5.stochastic_depth, features.5.0.stochastic_depth, features.5.1.stochastic_depth, features.5.2.stochastic_depth, features.5.3.stochastic_depth, features.5.4.stochastic_depth, features.5.5.stochastic_depth, features.6.0.stochastic_depth, features.6.1.stochastic_depth, features.6.2.stochastic_depth, features.6.3.stochastic_depth, features.6.4.stochastic_depth, features.6.5.stochastic_depth, features.6.6.stochastic_depth, features.6.7.stochastic_depth, features.7.0.stochastic_depth, features.7.1.stochastic_depth
# Flops: 117700032.000000, Param size: 27777126.000000MB
# Flops: 119.196768, Param size: 27.777126MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::silu_ encountered 116 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 40 time(s)
# Unsupported operator aten::sigmoid encountered 39 time(s)
# Unsupported operator aten::mul encountered 39 time(s)
# Unsupported operator aten::add_ encountered 32 time(s)
# Unsupported operator aten::dropout_ encountered 1 time(s)
# The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# features.1.0.stochastic_depth, features.1.1.stochastic_depth, features.1.2.stochastic_depth, features.2.0.stochastic_depth, features.2.1.stochastic_depth, features.2.2.stochastic_depth, features.2.3.stochastic_depth, features.2.4.stochastic_depth, features.3.0.stochastic_depth, features.3.1.stochastic_depth, features.3.2.stochastic_depth, features.3.3.stochastic_depth, features.3.4.stochastic_depth, features.4.0.stochastic_depth, features.4.1.stochastic_depth, features.4.2.stochastic_depth, features.4.3.stochastic_depth, features.4.4.stochastic_depth, features.4.5.stochastic_depth, features.4.6.stochastic_depth, features.5.0.stochastic_depth, features.5.1.stochastic_depth, features.5.2.stochastic_depth, features.5.3.stochastic_depth, features.5.4.stochastic_depth, features.5.5.stochastic_depth, features.5.6.stochastic_depth, features.6.0.stochastic_depth, features.6.1.stochastic_depth, features.6.2.stochastic_depth, features.6.3.stochastic_depth, features.6.4.stochastic_depth, features.6.5.stochastic_depth, features.6.6.stochastic_depth, features.6.7.stochastic_depth, features.6.8.stochastic_depth, features.7.0.stochastic_depth, features.7.1.stochastic_depth, features.7.2.stochastic_depth
# Flops: 169346080.000000, Param size: 39977142.000000MB
# Unsupported operator aten::silu_ encountered 134 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 46 time(s)
# Unsupported operator aten::sigmoid encountered 45 time(s)
# Unsupported operator aten::mul encountered 45 time(s)
# Unsupported operator aten::add_ encountered 38 time(s)
# Unsupported operator aten::dropout_ encountered 1 time(s)
# The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# features.1.0.stochastic_depth, features.1.1.stochastic_depth, features.1.2.stochastic_depth, features.2.0.stochastic_depth, features.2.1.stochastic_depth, features.2.2.stochastic_depth, features.2.3.stochastic_depth, features.2.4.stochastic_depth, features.2.5.stochastic_depth, features.3.0.stochastic_depth, features.3.1.stochastic_depth, features.3.2.stochastic_depth, features.3.3.stochastic_depth, features.3.4.stochastic_depth, features.3.5.stochastic_depth, features.4.0.stochastic_depth, features.4.1.stochastic_depth, features.4.2.stochastic_depth, features.4.3.stochastic_depth, features.4.4.stochastic_depth, features.4.5.stochastic_depth, features.4.6.stochastic_depth, features.4.7.stochastic_depth, features.5.0.stochastic_depth, features.5.1.stochastic_depth, features.5.2.stochastic_depth, features.5.3.stochastic_depth, features.5.4.stochastic_depth, features.5.5.stochastic_depth, features.5.6.stochastic_depth, features.5.7.stochastic_depth, features.6.0.stochastic_depth, features.6.1.stochastic_depth, features.6.10.stochastic_depth, features.6.2.stochastic_depth, features.6.3.stochastic_depth, features.6.4.stochastic_depth, features.6.5.stochastic_depth, features.6.6.stochastic_depth, features.6.7.stochastic_depth, features.6.8.stochastic_depth, features.6.9.stochastic_depth, features.7.0.stochastic_depth, features.7.1.stochastic_depth, features.7.2.stochastic_depth
# Flops: 171.283592, Param size: 39.977142MB
# Experiment results saved to model_spec.csv
# Flops: 264591360.000000, Param size: 62747286.000000MB
# Flops: 267.255392, Param size: 62.747286MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::silu_ encountered 163 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 56 time(s)
# Unsupported operator aten::sigmoid encountered 55 time(s)
# Unsupported operator aten::mul encountered 55 time(s)
# Unsupported operator aten::add_ encountered 48 time(s)
# Unsupported operator aten::dropout_ encountered 1 time(s)
# The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# features.1.0.stochastic_depth, features.1.1.stochastic_depth, features.1.2.stochastic_depth, features.1.3.stochastic_depth, features.2.0.stochastic_depth, features.2.1.stochastic_depth, features.2.2.stochastic_depth, features.2.3.stochastic_depth, features.2.4.stochastic_depth, features.2.5.stochastic_depth, features.2.6.stochastic_depth, features.3.0.stochastic_depth, features.3.1.stochastic_depth, features.3.2.stochastic_depth, features.3.3.stochastic_depth, features.3.4.stochastic_depth, features.3.5.stochastic_depth, features.3.6.stochastic_depth, features.4.0.stochastic_depth, features.4.1.stochastic_depth, features.4.2.stochastic_depth, features.4.3.stochastic_depth, features.4.4.stochastic_depth, features.4.5.stochastic_depth, features.4.6.stochastic_depth, features.4.7.stochastic_depth, features.4.8.stochastic_depth, features.4.9.stochastic_depth, features.5.0.stochastic_depth, features.5.1.stochastic_depth, features.5.2.stochastic_depth, features.5.3.stochastic_depth, features.5.4.stochastic_depth, features.5.5.stochastic_depth, features.5.6.stochastic_depth, features.5.7.stochastic_depth, features.5.8.stochastic_depth, features.5.9.stochastic_depth, features.6.0.stochastic_depth, features.6.1.stochastic_depth, features.6.10.stochastic_depth, features.6.11.stochastic_depth, features.6.12.stochastic_depth, features.6.2.stochastic_depth, features.6.3.stochastic_depth, features.6.4.stochastic_depth, features.6.5.stochastic_depth, features.6.6.stochastic_depth, features.6.7.stochastic_depth, features.6.8.stochastic_depth, features.6.9.stochastic_depth, features.7.0.stochastic_depth, features.7.1.stochastic_depth, features.7.2.stochastic_depth, features.7.3.stochastic_depth
# Flops: 87825152.000000, Param size: 19445758.000000MB
# Flops: 88.956608, Param size: 19.445758MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::silu_ encountered 102 time(s)
# Unsupported operator aten::add_ encountered 35 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 31 time(s)
# Unsupported operator aten::sigmoid encountered 30 time(s)
# Unsupported operator aten::mul encountered 30 time(s)
# Unsupported operator aten::dropout_ encountered 1 time(s)
# The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# features.1.0.stochastic_depth, features.1.1.stochastic_depth, features.2.0.stochastic_depth, features.2.1.stochastic_depth, features.2.2.stochastic_depth, features.2.3.stochastic_depth, features.3.0.stochastic_depth, features.3.1.stochastic_depth, features.3.2.stochastic_depth, features.3.3.stochastic_depth, features.4.0.stochastic_depth, features.4.1.stochastic_depth, features.4.2.stochastic_depth, features.4.3.stochastic_depth, features.4.4.stochastic_depth, features.4.5.stochastic_depth, features.5.0.stochastic_depth, features.5.1.stochastic_depth, features.5.2.stochastic_depth, features.5.3.stochastic_depth, features.5.4.stochastic_depth, features.5.5.stochastic_depth, features.5.6.stochastic_depth, features.5.7.stochastic_depth, features.5.8.stochastic_depth, features.6.0.stochastic_depth, features.6.1.stochastic_depth, features.6.10.stochastic_depth, features.6.11.stochastic_depth, features.6.12.stochastic_depth, features.6.13.stochastic_depth, features.6.14.stochastic_depth, features.6.2.stochastic_depth, features.6.3.stochastic_depth, features.6.4.stochastic_depth, features.6.5.stochastic_depth, features.6.6.stochastic_depth, features.6.7.stochastic_depth, features.6.8.stochastic_depth, features.6.9.stochastic_depth
# Flops: 214143872.000000, Param size: 51560610.000000MB
# Flops: 216.180992, Param size: 51.560610MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::silu_ encountered 147 time(s)
# Unsupported operator aten::add_ encountered 51 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 45 time(s)
# Unsupported operator aten::sigmoid encountered 44 time(s)
# Unsupported operator aten::mul encountered 44 time(s)
# Unsupported operator aten::dropout_ encountered 1 time(s)
# The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# features.1.0.stochastic_depth, features.1.1.stochastic_depth, features.1.2.stochastic_depth, features.2.0.stochastic_depth, features.2.1.stochastic_depth, features.2.2.stochastic_depth, features.2.3.stochastic_depth, features.2.4.stochastic_depth, features.3.0.stochastic_depth, features.3.1.stochastic_depth, features.3.2.stochastic_depth, features.3.3.stochastic_depth, features.3.4.stochastic_depth, features.4.0.stochastic_depth, features.4.1.stochastic_depth, features.4.2.stochastic_depth, features.4.3.stochastic_depth, features.4.4.stochastic_depth, features.4.5.stochastic_depth, features.4.6.stochastic_depth, features.5.0.stochastic_depth, features.5.1.stochastic_depth, features.5.10.stochastic_depth, features.5.11.stochastic_depth, features.5.12.stochastic_depth, features.5.13.stochastic_depth, features.5.2.stochastic_depth, features.5.3.stochastic_depth, features.5.4.stochastic_depth, features.5.5.stochastic_depth, features.5.6.stochastic_depth, features.5.7.stochastic_depth, features.5.8.stochastic_depth, features.5.9.stochastic_depth, features.6.0.stochastic_depth, features.6.1.stochastic_depth, features.6.10.stochastic_depth, features.6.11.stochastic_depth, features.6.12.stochastic_depth, features.6.13.stochastic_depth, features.6.14.stochastic_depth, features.6.15.stochastic_depth, features.6.16.stochastic_depth, features.6.17.stochastic_depth, features.6.2.stochastic_depth, features.6.3.stochastic_depth, features.6.4.stochastic_depth, features.6.5.stochastic_depth, features.6.6.stochastic_depth, features.6.7.stochastic_depth, features.6.8.stochastic_depth, features.6.9.stochastic_depth, features.7.0.stochastic_depth, features.7.1.stochastic_depth, features.7.2.stochastic_depth, features.7.3.stochastic_depth, features.7.4.stochastic_depth
# Flops: 474082560.000000, Param size: 114489542.000000MB
# Flops: 477.646528, Param size: 114.489542MB
# Experiment results saved to model_spec.csv
# Unsupported operator aten::silu_ encountered 203 time(s)
# Unsupported operator aten::add_ encountered 73 time(s)
# Unsupported operator aten::adaptive_avg_pool1d encountered 62 time(s)
# Unsupported operator aten::sigmoid encountered 61 time(s)
# Unsupported operator aten::mul encountered 61 time(s)
# Unsupported operator aten::dropout_ encountered 1 time(s)
# The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# features.1.0.stochastic_depth, features.1.1.stochastic_depth, features.1.2.stochastic_depth, features.1.3.stochastic_depth, features.2.0.stochastic_depth, features.2.1.stochastic_depth, features.2.2.stochastic_depth, features.2.3.stochastic_depth, features.2.4.stochastic_depth, features.2.5.stochastic_depth, features.2.6.stochastic_depth, features.3.0.stochastic_depth, features.3.1.stochastic_depth, features.3.2.stochastic_depth, features.3.3.stochastic_depth, features.3.4.stochastic_depth, features.3.5.stochastic_depth, features.3.6.stochastic_depth, features.4.0.stochastic_depth, features.4.1.stochastic_depth, features.4.2.stochastic_depth, features.4.3.stochastic_depth, features.4.4.stochastic_depth, features.4.5.stochastic_depth, features.4.6.stochastic_depth, features.4.7.stochastic_depth, features.4.8.stochastic_depth, features.4.9.stochastic_depth, features.5.0.stochastic_depth, features.5.1.stochastic_depth, features.5.10.stochastic_depth, features.5.11.stochastic_depth, features.5.12.stochastic_depth, features.5.13.stochastic_depth, features.5.14.stochastic_depth, features.5.15.stochastic_depth, features.5.16.stochastic_depth, features.5.17.stochastic_depth, features.5.18.stochastic_depth, features.5.2.stochastic_depth, features.5.3.stochastic_depth, features.5.4.stochastic_depth, features.5.5.stochastic_depth, features.5.6.stochastic_depth, features.5.7.stochastic_depth, features.5.8.stochastic_depth, features.5.9.stochastic_depth, features.6.0.stochastic_depth, features.6.1.stochastic_depth, features.6.10.stochastic_depth, features.6.11.stochastic_depth, features.6.12.stochastic_depth, features.6.13.stochastic_depth, features.6.14.stochastic_depth, features.6.15.stochastic_depth, features.6.16.stochastic_depth, features.6.17.stochastic_depth, features.6.18.stochastic_depth, features.6.19.stochastic_depth, features.6.2.stochastic_depth, features.6.20.stochastic_depth, features.6.21.stochastic_depth, features.6.22.stochastic_depth, features.6.23.stochastic_depth, features.6.24.stochastic_depth, features.6.3.stochastic_depth, features.6.4.stochastic_depth, features.6.5.stochastic_depth, features.6.6.stochastic_depth, features.6.7.stochastic_depth, features.6.8.stochastic_depth, features.6.9.stochastic_depth, features.7.0.stochastic_depth, features.7.1.stochastic_depth, features.7.2.stochastic_depth, features.7.3.stochastic_depth, features.7.4.stochastic_depth, features.7.5.stochastic_depth, features.7.6.stochastic_depth

# %% [markdown]
# # 결과 결합

# %%
import pandas as pd

# %%
lat_df = pd.read_csv('vision.csv')
spec_df = pd.read_csv('model_spec.csv')

# %%
lat_df.head()
# Out:
#   dataset  batch         model hardware device   latency
# 0     uci      1  mobilenet_v2       pc    cpu  0.001731
# 1     uci      1  mobilenet_v2       pc    cpu  0.001715
# 2     uci      1  mobilenet_v2       pc    cpu  0.001668
# 3     uci      1  mobilenet_v2       pc    cpu  0.001738
# 4     uci      1  mobilenet_v2       pc    cpu  0.001676

# %%
spec_df.head()
# Out:
#   dataset               Model  Params(M)   FLOPs(M)
# 0     uci        mobilenet_v2   2.188454  12.144896
# 1     uci  mobilenet_v3_small   1.477206   3.364792
# 2     uci  mobilenet_v3_large   4.138822  11.046616
# 3     uci          mnasnet0_5   0.880974   4.466048
# 4     uci         mnasnet0_75   1.800342   9.187776

# %% [markdown]
# # calculate latency mean & std

# %% [markdown]
# mean

# %%
test = lat_df.groupby(['model', 'device', 'batch']).mean()
test
# Out:
# C:\Users\ai-ws\AppData\Local\Temp\ipykernel_32432\3156294001.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   test = lat_df.groupby(['model', 'device', 'batch']).mean()
#                                    latency
# model              device batch
# efficientnet_b0    cpu    1       0.001751
#                    gpu    1       7.834549
# efficientnet_b1    cpu    1       0.001783
#                    gpu    1      11.332993
# efficientnet_b2    cpu    1       0.001798
# ...                                    ...
# shufflenet_v2_x2_0 gpu    1       5.493936
# squeezenet1_0      cpu    1       0.001667
#                    gpu    1       2.444405
# squeezenet1_1      cpu    1       0.001653
#                    gpu    1       2.436532
#
# [62 rows x 1 columns]

# %%
test = test.reset_index()
test
# Out:
#                  model device  batch    latency
# 0      efficientnet_b0    cpu      1   0.001751
# 1      efficientnet_b0    gpu      1   7.834549
# 2      efficientnet_b1    cpu      1   0.001783
# 3      efficientnet_b1    gpu      1  11.332993
# 4      efficientnet_b2    cpu      1   0.001798
# ..                 ...    ...    ...        ...
# 57  shufflenet_v2_x2_0    gpu      1   5.493936
# 58       squeezenet1_0    cpu      1   0.001667
# 59       squeezenet1_0    gpu      1   2.444405
# 60       squeezenet1_1    cpu      1   0.001653
# 61       squeezenet1_1    gpu      1   2.436532
#
# [62 rows x 4 columns]

# %%
temp = test[test['device'] == 'cpu'].iloc[:, [0,2]].copy()
temp.reset_index(drop=True, inplace=True)

# %%
temp['PC:CPU(ms)'] = test[test['device'] == 'cpu']['latency'].reset_index(drop=True)
temp['PC:GPU(ms)'] = test[test['device'] == 'gpu']['latency'].reset_index(drop=True)
temp
# Out:
#                  model  batch  PC:CPU(ms)  PC:GPU(ms)
# 0      efficientnet_b0      1    0.001751    7.834549
# 1      efficientnet_b1      1    0.001783   11.332993
# 2      efficientnet_b2      1    0.001798   11.135680
# 3      efficientnet_b3      1    0.001788   12.788084
# 4      efficientnet_b4      1    0.001829   15.888953
# 5      efficientnet_b5      1    0.001828   19.575624
# 6      efficientnet_b6      1    0.001818   22.704545
# 7      efficientnet_b7      1    0.001870   27.817578
# 8    efficientnet_v2_l      1    0.001848   35.994316
# 9    efficientnet_v2_m      1    0.001847   25.563504
# 10   efficientnet_v2_s      1    0.001857   17.803161
# 11          mnasnet0_5      1    0.001688    4.298723
# 12         mnasnet0_75      1    0.001709    4.355154
# 13          mnasnet1_0      1    0.001709    4.422530
# 14          mnasnet1_3      1    0.001727    4.462775
# 15        mobilenet_v2      1    0.001717    4.564532
# 16  mobilenet_v3_large      1    0.001740    5.600774
# 17  mobilenet_v3_small      1    0.001711    4.924629
# 18           resnet101      1    0.001796   13.202229
# 19            resnet18      1    0.001715    2.774208
# 20            resnet34      1    0.001686    5.323216
# 21            resnet50      1    0.001702    5.356506
# 22    resnext101_32x8d      1    0.001843   13.609392
# 23    resnext101_64x4d      1    0.001817   11.274258
# 24     resnext50_32x4d      1    0.001795    5.581768
# 25  shufflenet_v2_x0_5      1    0.001698    5.373840
# 26  shufflenet_v2_x1_0      1    0.001716    5.394307
# 27  shufflenet_v2_x1_5      1    0.001719    5.469634
# 28  shufflenet_v2_x2_0      1    0.001722    5.493936
# 29       squeezenet1_0      1    0.001667    2.444405
# 30       squeezenet1_1      1    0.001653    2.436532

# %%
temp.columns = ['Model', 'Batch', 'PC:CPU(ms)', 'PC:GPU(ms)']
temp
# Out:
#                  Model  Batch  PC:CPU(ms)  PC:GPU(ms)
# 0      efficientnet_b0      1    0.001751    7.834549
# 1      efficientnet_b1      1    0.001783   11.332993
# 2      efficientnet_b2      1    0.001798   11.135680
# 3      efficientnet_b3      1    0.001788   12.788084
# 4      efficientnet_b4      1    0.001829   15.888953
# 5      efficientnet_b5      1    0.001828   19.575624
# 6      efficientnet_b6      1    0.001818   22.704545
# 7      efficientnet_b7      1    0.001870   27.817578
# 8    efficientnet_v2_l      1    0.001848   35.994316
# 9    efficientnet_v2_m      1    0.001847   25.563504
# 10   efficientnet_v2_s      1    0.001857   17.803161
# 11          mnasnet0_5      1    0.001688    4.298723
# 12         mnasnet0_75      1    0.001709    4.355154
# 13          mnasnet1_0      1    0.001709    4.422530
# 14          mnasnet1_3      1    0.001727    4.462775
# 15        mobilenet_v2      1    0.001717    4.564532
# 16  mobilenet_v3_large      1    0.001740    5.600774
# 17  mobilenet_v3_small      1    0.001711    4.924629
# 18           resnet101      1    0.001796   13.202229
# 19            resnet18      1    0.001715    2.774208
# 20            resnet34      1    0.001686    5.323216
# 21            resnet50      1    0.001702    5.356506
# 22    resnext101_32x8d      1    0.001843   13.609392
# 23    resnext101_64x4d      1    0.001817   11.274258
# 24     resnext50_32x4d      1    0.001795    5.581768
# 25  shufflenet_v2_x0_5      1    0.001698    5.373840
# 26  shufflenet_v2_x1_0      1    0.001716    5.394307
# 27  shufflenet_v2_x1_5      1    0.001719    5.469634
# 28  shufflenet_v2_x2_0      1    0.001722    5.493936
# 29       squeezenet1_0      1    0.001667    2.444405
# 30       squeezenet1_1      1    0.001653    2.436532

# %%
result_df = pd.merge(spec_df, temp, on='Model', how='left')
result_df
# Out:
#    dataset               Model   Params(M)    FLOPs(M)  Batch  PC:CPU(ms)  \
# 0      uci        mobilenet_v2    2.188454   12.144896      1    0.001717
# 1      uci  mobilenet_v3_small    1.477206    3.364792      1    0.001711
# 2      uci  mobilenet_v3_large    4.138822   11.046616      1    0.001740
# 3      uci          mnasnet0_5    0.880974    4.466048      1    0.001688
# 4      uci         mnasnet0_75    1.800342    9.187776      1    0.001709
# 5      uci          mnasnet1_0    2.984238   14.813952      1    0.001709
# 6      uci          mnasnet1_3    4.844518   24.318848      1    0.001727
# 7      uci  shufflenet_v2_x0_5    0.341534    1.744768      1    0.001698
# 8      uci  shufflenet_v2_x1_0    1.244778    6.751744      1    0.001716
# 9      uci  shufflenet_v2_x1_5    2.462238   13.719424      1    0.001719
# 10     uci  shufflenet_v2_x2_0    5.326186   28.526080      1    0.001722
# 11     uci            resnet18    3.849222   22.107648      1    0.001715
# 12     uci            resnet34    7.223558   45.045248      1    0.001686
# 13     uci            resnet50    7.223558   45.045248      1    0.001702
# 14     uci           resnet101   28.276230  199.907328      1    0.001796
# 15     uci     resnext50_32x4d   22.042374  142.489600      1    0.001795
# 16     uci    resnext101_32x8d   79.633158  574.961664      1    0.001843
# 17     uci    resnext101_64x4d   77.854470  562.477056      1    0.001817
# 18     uci       squeezenet1_0    0.359782    5.210352      1    0.001667
# 19     uci       squeezenet1_1    0.356358    3.169200      1    0.001653
# 20     uci     efficientnet_b0    3.872482   17.649408      1    0.001751
# 21     uci     efficientnet_b1    6.321478   27.602704      1    0.001783
# 22     uci     efficientnet_b2    7.492776   32.601984      1    0.001798
# 23     uci     efficientnet_b3   10.416134   45.899392      1    0.001788
# 24     uci     efficientnet_b4   17.124974   74.797624      1    0.001829
# 25     uci     efficientnet_b5   27.777126  119.196768      1    0.001828
# 26     uci     efficientnet_b6   39.977142  171.283592      1    0.001818
# 27     uci     efficientnet_b7   62.747286  267.255392      1    0.001870
# 28     uci   efficientnet_v2_s   19.445758   88.956608      1    0.001857
# 29     uci   efficientnet_v2_m   51.560610  216.180992      1    0.001847
# 30     uci   efficientnet_v2_l  114.489542  477.646528      1    0.001848
#
#     PC:GPU(ms)
# 0     4.564532
# 1     4.924629
# 2     5.600774
# 3     4.298723
# 4     4.355154
# 5     4.422530
# 6     4.462775
# 7     5.373840
# 8     5.394307
# 9     5.469634
# 10    5.493936
# 11    2.774208
# 12    5.323216
# 13    5.356506
# 14   13.202229
# 15    5.581768
# 16   13.609392
# 17   11.274258
# 18    2.444405
# 19    2.436532
# 20    7.834549
# 21   11.332993
# 22   11.135680
# 23   12.788084
# 24   15.888953
# 25   19.575624
# 26   22.704545
# 27   27.817578
# 28   17.803161
# 29   25.563504
# 30   35.994316

# %% [markdown]
# * save result of vision model

# %%
result_df.to_csv('result_vismodel.csv', index=False)
